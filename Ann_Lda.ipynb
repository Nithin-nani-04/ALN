# %% [markdown]
# <a href="https://colab.research.google.com/github/Nithin-nani-04/ALN/blob/main/Ann_Lda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
data=load_iris()
x,y=data.data,data.target
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=101)

# %%
x_test.shape,x_train.shape
# Out:
# ((45, 4), (105, 4))

# %%
import matplotlib.pyplot as plt
plt.scatter(x_train[:,0],x_train[:,1],c=y_train,cmap='rainbow',alpha=0.7,edgecolors='b')

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
lda=LinearDiscriminantAnalysis(n_components=2)
x_train=lda.fit_transform(x_train,y_train)
x_test=lda.transform(x_test)
x_test.shape,x_train.shape
# Out:
# ((45, 2), (105, 2))

# %%
plt.scatter(x_train[:,1],x_train[:,0],c=y_train,cmap='rainbow',alpha=0.5,edgecolors='b')
