# %% [markdown]
# <a href="https://colab.research.google.com/github/Nithin-nani-04/ALN/blob/main/ann_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
data=load_iris()
x,y=data.data,data.target
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=101)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.scatter(x[:,0],x[:,1],c=y)
print(x_train.shape)
print(x_test.shape)
# Out:
# (105, 2)
# (45, 2)

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
lda=LinearDiscriminantAnalysis(n_components=2)
x_train=lda.fit_transform(x_train,y_train)
x_test=lda.transform(x_test)

print(x_train.shape)
print(x_test.shape)
# Out:
# (105, 2)
# (45, 2)

# %%
plt.scatter(x_train[:,1],x_train[:,0],c=y_train)
